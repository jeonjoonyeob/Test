# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonjoonyeob/Test/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !curl -L "https://public.roboflow.com/ds/C3QR5pjnkR?key=xf3RnHx3VX" > roboflow.zip; unzip roboflow.zip; rm roboflow.zip

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 6233, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 6233 (delta 10), reused 14 (delta 7), pack-reused 6206
# Receiving objects: 100% (6233/6233), 8.49 MiB | 34.89 MiB/s, done.
# Resolving deltas: 100% (4265/4265), done.

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt

# %%
# %cat /content/dataset/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
#
# nc: 1
# names: ['pistol']

# %%
# %cd /
from glob import glob
img_list = glob('/content/dataset/export/images/*.jpg')
print(len(img_list))
# Out:
# /
# 2971

# %%
from  sklearn.model_selection import train_test_split

train_img_list, val_img_list = train_test_split(img_list, test_size=0.2, random_state=2000)
print(len(train_img_list), len(val_img_list))
# Out:
# 2376 595

# %%
with open('content/dataset/train.txt', 'w') as f:
  f.write('\n'.join(train_img_list)+'\n')

with open('/content/dataset/val.txt', 'w') as f:
  f.write('\n'.join(val_img_list)+'\n')

# %%
import yaml
with open('/content/dataset/data.yaml', 'r') as f:
  data = yaml.load(f)

print(data)

data['train'] = '/content/dataset/train.txt'
data['val'] = '/content/dataset/val.txt'

with open('/content/dataset/data.yaml', 'w') as f:
  yaml.dump(data, f)

  print(data)
# Out:
# {'train': '../train/images', 'val': '../valid/images', 'nc': 1, 'names': ['pistol']}
# {'train': '/content/dataset/train.txt', 'val': '/content/dataset/val.txt', 'nc': 1, 'names': ['pistol']}
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
 # %cd /content/yolov5/

 # !python train.py --img 416 --batch 16 --epochs 50 --data /content/dataset/data.yaml --cfg ./models/yolov5s.yaml --weights yolov5s.pt --name gun_yolov5s_results

# %%
# %load_ext tensorboard
# %tensorboard --logdir /content/yolov5/runs/

# %%
from IPython.display import Image

import os 

val_img_path = val_img_list[100]

# !python detect.py --weights /content/yolov5/runs/train/gun_yolov5s_results/weights/best.pt --img 416 --conf 0.5 --source "{val_img_path}"

Image(os.path.join('/content/yolov5/runs/detect/exp', os.path.basename(val_img_path)))
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.5, device='', exist_ok=False, hide_conf=False, hide_labels=False, img_size=416, iou_thres=0.45, line_thickness=3, name='exp', nosave=False, project='runs/detect', save_conf=False, save_crop=False, save_txt=False, source='/content/dataset/export/images/armas (2568)_jpg.rf.fb3d0f2eb4ccaeac9281c46950a401ef.jpg', update=False, view_img=False, weights=['/content/yolov5/runs/train/gun_yolov5s_results/weights/best.pt'])
# YOLOv5 🚀 v5.0-76-g57b0d3a torch 1.8.1+cu101 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7053910 parameters, 0 gradients, 16.3 GFLOPS
# image 1/1 /content/dataset/export/images/armas (2568)_jpg.rf.fb3d0f2eb4ccaeac9281c46950a401ef.jpg: 416x416 1 pistol, Done. (0.010s)
# Results saved to runs/detect/exp
# Done. (0.019s)

# %%
import torch
from IPython.display import Image, clear_output

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.8.1+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15109MB, multi_processor_count=40)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5dc83c8f-dda1-4222-9e4d-347043b82b9f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5dc83c8f-dda1-4222-9e4d-347043b82b9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HK P30L Review_ John Wick's Pistol.mp4 to HK P30L Review_ John Wick's Pistol.mp4

# %%
# !python detect.py --weights /content/yolov5/runs/train/gun_yolov5s_results/weights/best.pt --source /content/yolov5/
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# video 2/2 (16471/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 2 pistols, Done. (0.009s)
# video 2/2 (16472/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 3 pistols, Done. (0.009s)
# video 2/2 (16473/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 3 pistols, Done. (0.009s)
# video 2/2 (16474/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 3 pistols, Done. (0.009s)
# video 2/2 (16475/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 3 pistols, Done. (0.009s)
# video 2/2 (16476/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 3 pistols, Done. (0.009s)
# video 2/2 (16477/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 3 pistols, Done. (0.009s)
# video 2/2 (16478/21468) /content/yolov5/HK P30L Review_ John Wick's Pistol.mp4: 384x640 2 pistols, Done. (0.011s)
# ...
